# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df1 = pd.read_csv('187.tips.csv')
df2 = pd.read_csv('204.ece.csv')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df2.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1       ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2       ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3       ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4       ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
#
#    Magnitude                                        Subject  \
# 0          6  Electronic Card Transactions (ANZSIC06) - ECT
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
# 3          6  Electronic Card Transactions (ANZSIC06) - ECT
# 4          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# 1  Total values - Electronic card transactions A/...         Actual
# 2  Total values - Electronic card transactions A/...         Actual
# 3  Total values - Electronic card transactions A/...         Actual
# 4  Total values - Electronic card transactions A/...         Actual
#
#          Series_title_2 Series_title_3  Series_title_4  Series_title_5
# 0  RTS total industries            NaN             NaN             NaN
# 1  RTS total industries            NaN             NaN             NaN
# 2  RTS total industries            NaN             NaN             NaN
# 3  RTS total industries            NaN             NaN             NaN
# 4  RTS total industries            NaN             NaN             NaN

# %%
x1 = np.random.rand(100,5)
x2 = np.random.rand(10,5)

# %%
df3 = pd.DataFrame(x1,columns=['a','b','c','d','e'])
df4 = pd.DataFrame(x2,columns=['a','b','c','d','e'])

# %%
df3.head()
# Out:
#           a         b         c         d         e
# 0  0.126761  0.070533  0.490435  0.564890  0.659137
# 1  0.808794  0.759073  0.868900  0.052900  0.935491
# 2  0.979641  0.580821  0.057773  0.034799  0.865708
# 3  0.592215  0.470222  0.904068  0.619990  0.738548
# 4  0.171523  0.929228  0.009994  0.080702  0.861967

# %%
df4.head()
# Out:
#           a         b         c         d         e
# 0  0.121245  0.821234  0.198073  0.798905  0.295718
# 1  0.822837  0.186398  0.584503  0.829954  0.938494
# 2  0.270625  0.080891  0.399606  0.407389  0.356452
# 3  0.540574  0.507378  0.522365  0.331825  0.244746
# 4  0.200570  0.208105  0.082262  0.701405  0.427531

# %% [markdown]
# ## Point Plot

# %%
df3.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df4.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df1.plot.scatter(x='tip',y='total_bill')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
df2.plot.scatter(x='Period',y='Magnitude')
# Out:
# <AxesSubplot:xlabel='Period', ylabel='Magnitude'>

# %% [markdown]
# ## Line Plots

# %%
df1.plot.line()
# Out:
# <AxesSubplot:>

# %%
df2.plot.line()
# Out:
# <AxesSubplot:>

# %%
df3.plot.line()
# Out:
# <AxesSubplot:>

# %%
df4.plot.line()
# Out:
# <AxesSubplot:>

# %%
df1.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Distribution Plot

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df4.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1.plot.area()
# Out:
# <AxesSubplot:>

# %%
df3.plot.area()
# Out:
# <AxesSubplot:>

# %%
df4.plot.area(alpha=0.6)
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df3.plot.box()
# Out:
# <AxesSubplot:>

# %%
df4.plot.box()
# Out:
# <AxesSubplot:>

# %%
df1.plot.hexbin(x='total_bill',y='tip',gridsize=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df2.plot.hexbin(x='Period',y='Magnitude',gridsize=10)
# Out:
# <AxesSubplot:xlabel='Period', ylabel='Magnitude'>

# %%
df3.plot.hexbin(x='a',y='b',gridsize=10)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df4.plot.hexbin(x='a',y='b',gridsize=10)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
